# %%
# !python -m venv .venv

# %%
# !source .venv/bin/activate

# %%
# !python3 -m pip install nbformat
# Out:
# Collecting nbformat
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/a9/82/0340caa499416c78e5d8f5f05947ae4bc3cba53c9f038ab6e9ed964e22f1/nbformat-5.10.4-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/a9/82/0340caa499416c78e5d8f5f05947ae4bc3cba53c9f038ab6e9ed964e22f1/nbformat-5.10.4-py3-none-any.whl.metadata
#   WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/a9/82/0340caa499416c78e5d8f5f05947ae4bc3cba53c9f038ab6e9ed964e22f1/nbformat-5.10.4-py3-none-any.whl.metadata
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting fastjsonschema>=2.15 (from nbformat)
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting jsonschema>=2.6 (from nbformat)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./aa/.venv/lib/python3.11/site-packages (from nbformat) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in ./aa/.venv/lib/python3.11/site-packages (from nbformat) (5.14.2)
# Collecting attrs>=22.2.0 (from jsonschema>=2.6->nbformat)
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=2.6->nbformat)
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=2.6->nbformat)
#   Downloading referencing-0.34.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=2.6->nbformat)
#   Downloading rpds_py-0.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: platformdirs>=2.5 in ./aa/.venv/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.2.0)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 174.8 kB/s eta 0:00:00a 0:00:01
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 186.8 kB/s eta 0:00:00a 0:00:01
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading referencing-0.34.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 1.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: fastjsonschema, rpds-py, attrs, referencing, jsonschema-specifications, jsonschema, nbformat
# Successfully installed attrs-23.2.0 fastjsonschema-2.19.1 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 nbformat-5.10.4 referencing-0.34.0 rpds-py-0.18.0

# %%
# !python3 -m pip install Simple-Network
# Out:
# Collecting Simple-Network
#   Using cached Simple_Network-0.1.0-py3-none-any.whl.metadata (6.4 kB)
# Collecting plotly (from Simple-Network)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/00/4e/6258fc3b26f1f7abd1b2e75b1e9e4f12f13584136e2e1549f995ff4c6b7b/plotly-5.20.0-py3-none-any.whl.metadata
#   Downloading plotly-5.20.0-py3-none-any.whl.metadata (7.0 kB)
# Collecting numpy (from Simple-Network)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting tenacity>=6.2.0 (from plotly->Simple-Network)
#   Using cached tenacity-8.2.3-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: packaging in ./aa/.venv/lib/python3.11/site-packages (from plotly->Simple-Network) (24.0)
# Using cached Simple_Network-0.1.0-py3-none-any.whl (7.0 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Downloading plotly-5.20.0-py3-none-any.whl (15.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 2.0 MB/s eta 0:00:0000:0100:01
# Using cached tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity, numpy, plotly, Simple-Network
# Successfully installed Simple-Network-0.1.0 numpy-1.26.4 plotly-5.20.0 tenacity-8.2.3

# %%
from simpleN import MultilayerNetwork, Visualize

# %%
#add_layer(self, layer_name)
#add_node(self, layer_name, node )
#def add_edge(self, node1, node2, layer_name, weight=1)

# %%
G = MultilayerNetwork()

# %%
G.add_layer('test_1')
G.add_layer('test_2')

# %%
for node_ in range(1000) :
    G.add_node(layer_name='test_1', node= node_)

# %%
for node_ in range(1000, 2000) :
    G.add_node(layer_name='test_2', node= node_)

# %%
for i in range(0, 500, 5 ) :
    j = i + 500
    G.add_edge(node1= i, node2= j, layer_name='test_1')

# %%
for i in range(1200, 590, 3 ) :
    j = i + 400
    G.add_edge(node1= i, node2= j, layer_name='test_2')

# %%
for i in range(400, 800, 5 ) :
    for j in range( 1001, 1400, 5) :
        G.add_inter_layer_edge(node1= i, layer1= 'test_1', node2= j, layer2='test_2')

# %%
Visualize(G).show_graph()

# %%
G = MultilayerNetwork()

# %%
G.add_layer('test_1')
G.add_layer('test_2')

# %%
for node_ in range(100) :
    G.add_node(layer_name='test_1', node= node_)

# %%
for node_ in range(100, 200) :
    G.add_node(layer_name='test_2', node= node_)

# %%
for i in range(0, 50, 2 ) :
    j = i + 50
    G.add_edge(node1= i, node2= j, layer_name='test_1')

# %%
for i in range(120, 170, 2 ) :
    j = i + 25
    G.add_edge(node1= i, node2= j, layer_name='test_2')

# %%
for i in range(40, 80, 2 ) :
    for j in range( 101, 140, 2) :
        G.add_inter_layer_edge(node1= i, layer1= 'test_1', node2= j, layer2='test_2')

# %%
Visualize(G).show_graph()

# %%
Visualize(G).show_graph(edge_visibility_threshold = 0.2)
